# %%
from pytorch_lightning.utilities import grad_norm
import torch
import torch.nn as nn 
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import numpy as np
from copy import deepcopy
from sklearn.metrics import silhouette_score
import pandas as pd 
import torch.optim as optim
from braingeneers.analysis import SpikeData
import os
import json
import pytorch_lightning as pl
from backbones import ResNet18Enc, ResNet18Dec
import wandb
import pickle
from tqdm import tqdm
import scanpy as sc 
import matplotlib.pyplot as plt 
from torch.optim.lr_scheduler import ReduceLROnPlateau
import anndata as an 
from pytorch_lightning.callbacks import ModelCheckpoint, LearningRateMonitor, EarlyStopping
import umap
from collections import Counter
import pandas as pd

# %%
isi = pd.read_csv('./lookuptable_csv/isitransposed.csv',index_col=0)
print(isi.head())
waveform = pd.read_csv('./lookuptable_csv/Waveforms.csv',index_col=0)
print(waveform.head())
labels = pd.read_csv('./lookuptable_csv/CellType.csv',index_col=0)
print(labels.head())
print(isi.shape, waveform.shape, labels.shape)
# Out:
#           1         2         3         4         5         6          7  \
# 1  0.656683  0.898352  0.546205  0.653815  2.299961  4.091594   6.022484
# 2  1.627675  2.226686  0.193406  1.763883  2.976058  3.961261   7.292329
# 3  0.267144  0.348055  0.444401  1.042197  3.405941  7.777678  15.745868
# 4  2.602021  3.817549  2.258365  2.445838  2.935041  3.461981   2.929513
# 5  1.226348  1.799233  1.596571  1.658325  2.028843  1.783042   1.932975
#
#            8          9         10  ...        91        92        93  \
# 1   5.600268  10.765050  25.834541  ...  0.000113  0.000047  0.000120
# 2   4.820220   6.955843   9.439580  ...  0.000409  0.000213  0.000170
# 3  14.660829  21.462748  30.102711  ...  0.000019  0.000009  0.000000
# 4   2.434259   3.952808   8.518674  ...  0.000014  0.000013  0.000024
# 5   1.371140   1.276015   1.908533  ...  0.000188  0.000134  0.000100
#
#          94        95        96        97        98        99       100
# 1  0.000055  0.000036  0.000013  0.000024  0.000000  0.000000  0.000005
# 2  0.000155  0.000040  0.000055  0.000000  0.000015  0.000014  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  0.000000  0.000000  0.000009  0.000000  0.000000  0.000000  0.000000
# 5  0.000030  0.000028  0.000025  0.000008  0.000000  0.000000  0.000000
#
# [5 rows x 100 columns]
#          V1        V2        V3        V4        V5        V6        V7  \
# 1  0.078527  0.083879  0.090635  0.098468  0.105855  0.111595  0.116873
# 2  0.071128  0.074955  0.084065  0.093248  0.099457  0.103567  0.113920
# 3  0.049946  0.055678  0.062102  0.062542  0.058840  0.055788  0.054621
# 4  0.081810  0.086731  0.089523  0.091230  0.095272  0.103515  0.110416
# 5  0.072557  0.079786  0.084748  0.087393  0.090872  0.098150  0.107360
#
#          V8        V9       V10  ...       V37       V38       V39       V40  \
# 1  0.121123  0.121711  0.119584  ...  0.250847  0.220434  0.193322  0.168322
# 2  0.132134  0.151251  0.170198  ...  0.353149  0.301354  0.254351  0.210311
# 3  0.055811  0.059486  0.064170  ...  0.249033  0.220096  0.187761  0.156934
# 4  0.113379  0.114725  0.116651  ...  0.232210  0.208238  0.188977  0.171024
# 5  0.116265  0.123510  0.130238  ...  0.250551  0.225013  0.200209  0.175762
#
#         V41       V42       V43       V44       V45       V46
# 1  0.143883  0.120783  0.099990  0.082162  0.067626  0.056142
# 2  0.164993  0.124104  0.093873  0.077360  0.064059  0.042820
# 3  0.131536  0.109390  0.087279  0.062763  0.039045  0.020281
# 4  0.150807  0.128740  0.107664  0.091661  0.078975  0.066213
# 5  0.151561  0.126474  0.101766  0.081350  0.066515  0.056265
#
# [5 rows x 46 columns]
#    V1
# 1  PV
# 2  PV
# 3  PV
# 4  PV
# 5  PV
# (430, 100) (430, 46) (430, 1)

# %%
#convert to numpy
isi_dist = isi.to_numpy()
waveform = waveform.to_numpy()
labels = labels.to_numpy()
print(isi.shape, waveform.shape, labels.shape)
# Out:
# (430, 100) (430, 46) (430, 1)

# %%
#Count the number of unique labels
print(Counter(labels[:,0]))
# Out:
# Counter({'PV': 186, 'SST': 115, 'Pyra': 44, 'Axo_': 35, 'Juxt': 23, 'VIP': 14, 'VGAT': 13})

# %%
np.unique(labels)
#Rename the labels in the numpy array
labels[labels == 'Axo_'] = 'PV'

# %%
min_val = np.min(waveform)
max_val = np.max(waveform)
waveforms = (waveform - min_val) / (max_val - min_val)
# Scale to range [-1, 1]
waveforms = waveforms * 2 - 1
#waveforms = (waveforms - waveforms.mean()) / waveforms.std()
#0 1 normalization
#waveforms = (waveforms - waveforms.min()) / (waveforms.max() - waveforms.min())

isi_dists = isi_dist / isi_dist.sum(axis=1, keepdims=True)

# %%
type(isi_dists[0])
type(waveforms[0])
#Encode labels
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
labels = le.fit_transform(labels)
print(Counter(labels))
# Out:
# Counter({1: 221, 3: 115, 2: 44, 0: 23, 5: 14, 4: 13})
# /Users/jesusgf/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
indices_wf = [i for i in range(0, waveforms.shape[1])]
indices_isi = [i for i in range(0, isi_dists.shape[1])]
plt.figure(figsize=(10, 10))
panel1 = plt.axes([0.1, 0.1, 0.4, 0.4])
panel2 = plt.axes([0.1, 0.5, 0.4, 0.4])

#Color based on labels, use pastel colors

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
              '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']


for i in range(0, waveforms.shape[0]):
    panel1.plot(indices_wf, waveforms[i], c=colors[labels[i]], alpha=0.8, linewidth=1)

#panel1.scatter(indices_wf, waveform[0], c='r', s=1)
for i in range(0, isi_dists.shape[0]):
    #print(isi_dist[i])
    panel2.plot(indices_isi, isi_dists[i], c=colors[labels[i]], alpha=0.8, linewidth=1)
new_isi_dist = [x for x in isi_dists if not any(x > 0.35)]
mean_isi = np.mean(new_isi_dist, axis=0)
#Plot legend
for i in range(0, len(np.unique(labels))):
    panel2.plot([], [], c=colors[i], label=le.inverse_transform([i])[0])
#panel2.legend(loc='upper right', fontsize='large')
panel1.set_title('Waveforms', fontsize=16)
panel2.set_ylabel('Normalized ISI distribution', fontsize=16)
panel2.set_title('ISI', fontsize=16)
panel1.set_xlabel('Time', fontsize=16)
panel1.set_ylabel('Normalized Amplitude', fontsize=16)

#Increase the label font size


#panel2.plot(indices_isi, mean_isi, c='r')
# Out:
# Text(0, 0.5, 'Normalized Amplitude')

# %%
class EphysDatasetLabeled(Dataset):
    def __init__(self, waveforms, isi_dists,labels, normalize=True):
        self.waveforms = np.array(waveforms)
        self.isi_dists = np.array(isi_dists)
        self.labels = np.array(labels)
        #print(len(self.waveforms) , len(self.isi_dists), len(self.labels))
        assert len(self.waveforms) == len(self.isi_dists)
        assert len(self.waveforms) == len(self.labels)
        self.normalize = normalize
        
    def __getitem__(self, idx):
        waveform = torch.as_tensor(self.waveforms[idx, ...]).float()
        
        isi_dist = torch.as_tensor(self.isi_dists[idx, ...]).float()
        isi_dist = torch.log(isi_dist + 1)

        label = torch.as_tensor(self.labels[idx]).long()
        if self.normalize:
            #waveform = (waveform - waveform.mean()) / waveform.std()
            #0 1 normalization
            waveform = (waveform - waveform.min()) / (waveform.max() - waveform.min())
            isi_dist = (isi_dist - isi_dist.mean()) / isi_dist.std()

        waveform = waveform.view(1, 1, -1)
        waveform = F.interpolate(waveform, size=(50,), mode='linear').view(1, -1)
        
        isi_dist = isi_dist.view(1, 1, -1)
        isi_dist = F.interpolate(isi_dist, size=(100,), mode='linear').view(1, -1)

        return waveform, isi_dist, label
    
    def __len__(self):
        return len(self.waveforms)

# %%
import torch
is_torchvision_installed = True
try:
    import torchvision
except:
    is_torchvision_installed = False
import torch.utils.data
import random

class BalancedBatchSampler(torch.utils.data.sampler.Sampler):
    def __init__(self, dataset, labels=None):
        self.labels = labels
        self.dataset = dict()
        self.balanced_max = 0
        # Save all the indices for all the classes
        for idx in range(0, len(dataset)):
            label = self._get_label(dataset, idx)
            if label not in self.dataset:
                self.dataset[label] = list()
            self.dataset[label].append(idx)
            self.balanced_max = len(self.dataset[label]) \
                if len(self.dataset[label]) > self.balanced_max else self.balanced_max
        
        # Oversample the classes with fewer elements than the max
        for label in self.dataset:
            while len(self.dataset[label]) < self.balanced_max:
                self.dataset[label].append(random.choice(self.dataset[label]))
        self.keys = list(self.dataset.keys())
        self.currentkey = 0
        self.indices = [-1]*len(self.keys)

    def __iter__(self):
        while self.indices[self.currentkey] < self.balanced_max - 1:
            self.indices[self.currentkey] += 1
            yield self.dataset[self.keys[self.currentkey]][self.indices[self.currentkey]]
            self.currentkey = (self.currentkey + 1) % len(self.keys)
        self.indices = [-1]*len(self.keys)
    
    def _get_label(self, dataset, idx, labels = None):
        if self.labels is not None:
            return self.labels[idx].item()
        else:
            # Trying guessing
            dataset_type = type(dataset)
            if is_torchvision_installed and dataset_type is torchvision.datasets.MNIST:
                return dataset.train_labels[idx].item()
            elif is_torchvision_installed and dataset_type is torchvision.datasets.ImageFolder:
                return dataset.imgs[idx][1]
            else:
                raise Exception("You should pass the tensor of labels to the constructor as second argument")

    def __len__(self):
        return self.balanced_max*len(self.keys)

# %%
from sklearn.model_selection import train_test_split
#stratify train and val based on label
wf_train, wf_val, isi_train, isi_val, label_train, label_val = train_test_split(waveforms, isi_dists, labels, test_size=0.20, stratify=labels, random_state=42)
print(wf_train.shape, wf_val.shape, isi_train.shape, isi_val.shape, label_train.shape, label_val.shape)

dataset_train = EphysDatasetLabeled(wf_train, isi_train, label_train, normalize=False)
#Get all labels from dataset_train as a torch tensor
targets = torch.tensor([dataset_train[i][2] for i in range(len(dataset_train))])

sampler = BalancedBatchSampler(dataset_train,targets) #Ańadido aqui
#print(sampler)
dataloader_train = DataLoader(dataset_train, batch_size=32, sampler=sampler)

dataset_val = EphysDatasetLabeled(wf_val, isi_val, label_val, normalize=False)
targets_val = torch.tensor([dataset_val[i][2] for i in range(len(dataset_val))])
sampler = BalancedBatchSampler(dataset_val,targets_val) #Ańadido aqui
#print(sampler)
dataloader_val = DataLoader(dataset_val, batch_size=32, sampler=sampler)
#dataloader_val = DataLoader(dataset_val, batch_size=32, shuffle=False)

#Check distribution of label train and label val
print(np.unique(label_train, return_counts=True), np.unique(label_val, return_counts=True))
# Out:
# (344, 46) (86, 46) (344, 100) (86, 100) (344,) (86,)
# (array([0, 1, 2, 3, 4, 5]), array([ 18, 177,  35,  92,  11,  11])) (array([0, 1, 2, 3, 4, 5]), array([ 5, 44,  9, 23,  2,  3]))

# %%
#Loss function

def cross_entropy(preds, targets, reduction='none'):
    log_softmax = nn.LogSoftmax(dim=-1)
    loss = (-targets * log_softmax(preds)).sum(1)
    if reduction == "none":
        return loss
    elif reduction == "mean":
        return loss.mean()

class CLIPLoss(nn.Module):
    def __init__(self, temperature=0.5):
        super().__init__()
        self.register_buffer("temperature", torch.tensor(temperature))
            
    def forward(self, emb_i, emb_j):
        logits = (emb_i @ emb_j.T) / self.temperature
        emb_i_similarity = emb_i @ emb_i.T
        emb_j_similarity = emb_j @ emb_j.T

        targets = F.softmax(
            (emb_i_similarity + emb_j_similarity) / 2 * self.temperature, dim=-1
        )

        emb_i_loss = cross_entropy(logits, targets, reduction='none')
        emb_j_loss = cross_entropy(logits.T, targets.T, reduction='none')
        loss =  (emb_i_loss + emb_j_loss) / 2.0 # shape: (batch_size)
        return loss.mean()

# %%
class UnimodalModel(nn.Module):
    def __init__(self,z_dim,output_size, projector=True):
        super().__init__()
        
        self.encoder = nn.Sequential(
            ResNet18Enc(z_dim=z_dim),
            nn.Linear(z_dim*2, z_dim),
        )
        
        self.decoder = nn.Sequential(
            nn.BatchNorm1d(z_dim),
            nn.Linear(z_dim, z_dim*2),
            nn.BatchNorm1d(z_dim*2),
            ResNet18Dec(z_dim=z_dim,output_size = output_size)
        )
        
    def forward(self, x):
        x = x + torch.randn_like(x)*0.1
        enc_x = self.encoder(x)
        dec_x = self.decoder(enc_x)
        
        return enc_x, dec_x

class UnimodalEmbeddingModel(pl.LightningModule):
    def __init__(self, mode, base_model):
        super().__init__()
        assert mode in ("wave", "time")
        self.mode = mode
        self.model = base_model

        self.mse_loss = nn.MSELoss()
        self.val_loss = []
        self.train_loss = []

    def training_step(self, batch, batch_idx):
        if self.mode == "wave":
            data = batch[0]
        else:
            data = batch[1]
        
        enc, dec = self.model(data)
        loss = self.mse_loss(dec, data)
        
        norms = grad_norm(self.model.encoder, norm_type=2)
        self.log_dict(norms)
        norms = grad_norm(self.model.decoder, norm_type=2)
        self.log_dict(norms)

        self.train_loss.append(loss.item())
        self.log('train_loss', loss)
        
        return loss

    def validation_step(self, batch, batch_idx):
        if self.mode == "wave":
            data = batch[0]
        else:
            data = batch[1]
        
        enc, dec = self.model(data)
        loss = self.mse_loss(dec, data)
        
        self.val_loss.append(loss.item())
        self.log('val_loss', loss)
        
        return loss
    
    def on_validation_epoch_end(self):
        avg_loss = sum(self.val_loss) / len(self.val_loss)
        print(f"Average validation loss is {avg_loss:.2f}")
        self.val_loss = []
        
    def on_train_epoch_end(self):
        avg_loss = sum(self.train_loss) / len(self.train_loss)
        print(f"Average training loss is {avg_loss:.2f}")
        self.train_loss = []

    def configure_optimizers(self):
        optimizer = optim.AdamW(self.parameters(), lr=0.01)
        lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor=0.8)

        return {
            "lr_scheduler": {
                "scheduler": lr_scheduler,
                "monitor": "val_loss",
            },
            "optimizer": optimizer,
        }
    
    def forward(self, x):
        return self.model(x)

# %%
#Loading models trained on wave and time from warren
wave_model = UnimodalModel(z_dim=5,output_size=50)
time_model = UnimodalModel(z_dim=5,output_size=100)

# wave_model.load_state_dict(torch.load('./unimodal_model/wave_model_50_v2.pt'))
# time_model.load_state_dict(torch.load('./unimodal_model/time_model_100_v2.pt'))

# %%
#Finetuning data

# %%
#Fine-tune the wave model on the new dataset only using training data for 5 epochs no GPU
# wave_model_embed = UnimodalEmbeddingModel("wave", wave_model)
# trainer = pl.Trainer(max_epochs=5)
# trainer.fit(wave_model_embed, dataloader_train, dataloader_val)
# #Do the same thing for the time model
# time_model_embed = UnimodalEmbeddingModel("time", time_model)
# trainer = pl.Trainer(max_epochs=5)
# trainer.fit(time_model_embed, dataloader_train, dataloader_val)

# %%
#Save finetune models
# torch.save(wave_model_embed.model.state_dict(), './unimodal_model/wave_model_50_finetuned_v2.pt')
# torch.save(time_model_embed.model.state_dict(), './unimodal_model/time_model_100_finetuned_v2.pt')

# %%
#Load models
wave_model.load_state_dict(torch.load('./unimodal_model/wave_model_50_finetuned_v2.pt'))
time_model.load_state_dict(torch.load('./unimodal_model/time_model_100_finetuned_v2.pt'))
# Out:
# <All keys matched successfully>

# %%
embedding_waveform = []
embedding_isi = []
labels = []
for i, (wave, time,label) in enumerate(dataloader_train):
    e_wave,d_wave = wave_model(wave)
    e_time,d_time = time_model(time)
    embedding_waveform.append(e_wave)
    embedding_isi.append(e_time)
    #print(label)
    labels.append(label)

# %%
embedding_waveform = torch.cat(embedding_waveform, dim=0)
embedding_isi = torch.cat(embedding_isi, dim=0)

# %%
#Run Umap in the embeddings
embedding_waveform = embedding_waveform.detach().numpy()
embedding_isi = embedding_isi.detach().numpy()
labels = torch.cat(labels, dim=0).detach().numpy()

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
#Calculate UMAPs with the embeddings
kmeans_waveform = KMeans(n_clusters=6, random_state=42).fit(embedding_waveform)
kmeans_isi = KMeans(n_clusters=6, random_state=42).fit(embedding_isi)
#Save the kmeans labels
kmeans_waveform_labels = kmeans_waveform.labels_
kmeans_isi_labels = kmeans_isi.labels_
#Create a pandas dataframe with the predicted labels and the real label
df = pd.DataFrame({'Waveform': kmeans_waveform_labels, 'ISI': kmeans_isi_labels, 'Real': labels})
#Create a crosstab to see the distribution of the labels
dist_waveform = pd.crosstab(df['Waveform'], df['Real'])

dist_isi = pd.crosstab(df['ISI'], df['Real'])

#Compute confusion matrix
cm_waveform = confusion_matrix(labels, kmeans_waveform_labels, normalize='true')
cm_isi = confusion_matrix(labels, kmeans_isi_labels, normalize='true')

#Plot confusion matrix
disp_waveform = ConfusionMatrixDisplay(confusion_matrix=cm_waveform,display_labels=le.inverse_transform([0,1,2,3,4,5]))
disp_waveform.plot(cmap=plt.cm.Blues)
plt.title("Waveform")
plt.show()

disp_isi = ConfusionMatrixDisplay(confusion_matrix=cm_isi,display_labels=le.inverse_transform([0,1,2,3,4,5]))
disp_isi.plot(cmap=plt.cm.Blues)
plt.title("ISI")
plt.show()

# %%
joint_embeddings = np.concatenate([embedding_waveform, embedding_isi], axis=1)

# %%
#Do the same thing with Knearst neighbors
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

neigh_waveform = KNeighborsClassifier(n_neighbors=5)
neigh_waveform.fit(embedding_waveform, labels)
neigh_isi = KNeighborsClassifier(n_neighbors=5)
neigh_isi.fit(embedding_isi, labels)
neigh_joint = KNeighborsClassifier(n_neighbors=5)
neigh_joint.fit(joint_embeddings, labels)


knn_waveform_labels = neigh_waveform.predict(embedding_waveform)
knn_isi_labels = neigh_isi.predict(embedding_isi)
knn_joint_labels = neigh_joint.predict(joint_embeddings)

#Create a pandas dataframe with the predicted labels and the real label
df_knn = pd.DataFrame({'Waveform': knn_waveform_labels, 'ISI': knn_isi_labels, 'Real': labels})
#Create a crosstab to see the distribution of the labels
dist_waveform_knn = pd.crosstab(df_knn['Waveform'], df_knn['Real'])

dist_isi_knn = pd.crosstab(df_knn['ISI'], df_knn['Real'])

dist_joint_knn = pd.crosstab(df_knn['Waveform'], df_knn['Real'])
#Compute confusion matrix
cm_waveform_knn = confusion_matrix(labels, knn_waveform_labels, normalize='true')   
cm_isi_knn = confusion_matrix(labels, knn_isi_labels, normalize='true')
cm_joint_knn = confusion_matrix(labels, knn_joint_labels, normalize='true')

#Plot confusion matrix
disp_waveform_knn = ConfusionMatrixDisplay(confusion_matrix=cm_waveform_knn)
disp_waveform_knn.plot(cmap=plt.cm.Blues)
plt.title("Waveform")
plt.show()

disp_isi_knn = ConfusionMatrixDisplay(confusion_matrix=cm_isi_knn)
disp_isi_knn.plot(cmap=plt.cm.Blues)
plt.title("ISI")
plt.show()

disp_joint_knn = ConfusionMatrixDisplay(confusion_matrix=cm_joint_knn)
disp_joint_knn.plot(cmap=plt.cm.Blues)
plt.title("Joint")
plt.show()

# %%
#Check balanced accuracy
from sklearn.metrics import balanced_accuracy_score, accuracy_score
print(balanced_accuracy_score(labels, knn_waveform_labels), balanced_accuracy_score(labels, knn_isi_labels), balanced_accuracy_score(labels, knn_joint_labels))
print(accuracy_score(labels, knn_waveform_labels), accuracy_score(labels, knn_isi_labels), accuracy_score(labels, knn_joint_labels))
# Out:
# 0.7589453860640302 0.4500941619585688 0.6694915254237288
# 0.7589453860640302 0.4500941619585687 0.6694915254237288

# %%
#Calculate UMAP
embedding_waveform = umap.UMAP(n_neighbors=5, min_dist=0.3, n_components=2).fit_transform(embedding_waveform)
embedding_isi = umap.UMAP(n_neighbors=5, min_dist=0.3, n_components=2).fit_transform(embedding_isi)

# %%
#labelColor = ['r', 'g', 'b','gray','y','c','m','k','orange','purple']
#Choose a nice color palette
labelColor = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
              '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
labelColor = [labelColor[label] for label in labels]

# %%
#Create a legend based on labelColor and the cell type
unique_labels = np.unique(labels)
unique_labels = [str(le.inverse_transform([label])[0]) for label in unique_labels]
print(unique_labels)
# Out:
# ['Juxt', 'PV', 'Pyra', 'SST', 'VGAT', 'VIP']

# %%
figureWidth=8
figureHeight=6
plt.figure(figsize=(figureWidth,figureHeight))
panel1 = plt.axes([0.1, 0.1, 0.4, 0.8])
panel2 = plt.axes([0.5, 0.1, 0.4, 0.8])

panel1.scatter(embedding_waveform[:, 0], embedding_waveform[:, 1], color=labelColor, s=3, alpha=0.5)
panel1.set_title("Waveform Embedding")
panel1.set_xticks([])
panel1.set_yticks([])
panel2.scatter(embedding_isi[:, 0], embedding_isi[:, 1], color=labelColor, s=3, alpha=0.5)
panel2.set_title("ISI Embedding")
panel2.set_xticks([])
panel2.set_yticks([])

#Plot legend based on unique_labels and labelColor
panel2.legend(handles=[plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10, label=label) for color, label in zip(labelColor, unique_labels)], loc='center left', bbox_to_anchor=(1, 0.5))


plt.show()

# %%
from torch.nn.functional import normalize
class classification(nn.Module):
    def __init__(self, num_labels, **kwargs):
        super().__init__()
        #self.mixedModelAE = MixedModel(**kwargs)
        #self.mixedModelAE.load_state_dict(torch.load('MixedAutoEncoderTemplates.pt'))
        self.wave_model = UnimodalModel(z_dim=5,output_size=50)
        self.time_model = UnimodalModel(z_dim=5,output_size=100)
        self.wave_model.load_state_dict(torch.load('./unimodal_model/wave_model_50_finetuned.pt'))
        self.time_model.load_state_dict(torch.load('./unimodal_model/time_model_100_finetuned.pt'))
        for p in self.wave_model.parameters():
            p.requires_grad = False
        for p in self.time_model.parameters():
            p.requires_grad = False
        
        self.classifier = nn.Sequential(nn.Linear(kwargs['z_dim'] * 2, 64), nn.ReLU(),
                                         nn.Linear(64, num_labels))
        #self.classifier = nn.Sequential(nn.Linear(64 * 2, num_labels))
        

    def forward(self, wave,time):
        #e_wave, e_time, d_wave, d_time = self.mixedModelAE(wave,time)
        e_wave,d_wave = self.wave_model(wave)
        e_time,d_time = self.time_model(time)
        e_wave, e_time = normalize(e_wave), normalize(e_time)
        #print(e_wave.shape)
        #print(e_time.shape)
        x = torch.cat((e_wave, e_time), dim=-1).squeeze()
        #print(x.shape)
        output = self.classifier(x)    
        #print(output.shape)    
        return output

# %%
classifier = classification(num_labels=6, z_dim=5)
optimizer = torch.optim.AdamW(classifier.parameters(), lr=0.001)
loss_fn = nn.CrossEntropyLoss()

#Training the classifier

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay



def train_classifier(classifier, optim, loss_fn, train_loader, val_loader, epochs=10):
    for epoch in range(epochs):
        cum_loss = 0
        classifier.train()
        correct_train = 0
        total_train = 0
        for i, (wave, time,label) in enumerate(train_loader):
            optimizer.zero_grad()
            output = classifier(wave,time)
            train_predicted = torch.argmax(output, 1)
            total_train += time.size(0)
            correct_train += (train_predicted == label).sum().item()
            loss = loss_fn(output,label)
            cum_loss += loss.item()
            loss.backward()
            optimizer.step()
        print(f"Epoch {epoch} Iter {i} Loss {cum_loss/len(train_loader)}")
        print(f"Epoch {epoch} Iter {i} Train Accuracy {correct_train / total_train}")
        classifier.eval()
        correct = 0
        total = 0
        
        with torch.no_grad():
            for i, (wave, time,label) in enumerate(val_loader):
                output = classifier(wave,time)
                predicted = torch.argmax(output, 1)
                #print(predicted.shape)
                total += time.size(0)
                correct += (predicted == label).sum().item()
            print(f"Epoch {epoch} Validation Accuracy {correct / total}")

# %%
train_classifier(classifier, optimizer, loss_fn, dataloader_train, dataloader_val, epochs=100)
# Out:
# Epoch 0 Iter 33 Loss 1.7604128858622383
# Epoch 0 Iter 33 Train Accuracy 0.2617702448210923
# Epoch 0 Validation Accuracy 0.29924242424242425
# Epoch 1 Iter 33 Loss 1.7018259623471428
# Epoch 1 Iter 33 Train Accuracy 0.4058380414312618
# Epoch 1 Validation Accuracy 0.49242424242424243
# Epoch 2 Iter 33 Loss 1.6251325186561136
# Epoch 2 Iter 33 Train Accuracy 0.4651600753295669
# Epoch 2 Validation Accuracy 0.48863636363636365
# Epoch 3 Iter 33 Loss 1.5495913168963265
# Epoch 3 Iter 33 Train Accuracy 0.4661016949152542
# Epoch 3 Validation Accuracy 0.5151515151515151
# Epoch 4 Iter 33 Loss 1.482965564026552
# Epoch 4 Iter 33 Train Accuracy 0.4755178907721281
# Epoch 4 Validation Accuracy 0.5113636363636364
# Epoch 5 Iter 33 Loss 1.4248020543771631
# Epoch 5 Iter 33 Train Accuracy 0.4934086629001883
# Epoch 5 Validation Accuracy 0.5492424242424242
# Epoch 6 Iter 33 Loss 1.381441898205701
# Epoch 6 Iter 33 Train Accuracy 0.5037664783427496
# Epoch 6 Validation Accuracy 0.6060606060606061
# Epoch 7 Iter 33 Loss 1.351044030750499
# Epoch 7 Iter 33 Train Accuracy 0.5037664783427496
# Epoch 7 Validation Accuracy 0.5681818181818182
# Epoch 8 Iter 33 Loss 1.3336696694878971
# Epoch 8 Iter 33 Train Accuracy 0.5065913370998116
# Epoch 8 Validation Accuracy 0.5795454545454546
# Epoch 9 Iter 33 Loss 1.3164339205797981
# Epoch 9 Iter 33 Train Accuracy 0.5131826741996234
# Epoch 9 Validation Accuracy 0.5833333333333334
# Epoch 10 Iter 33 Loss 1.2972993026761448
# Epoch 10 Iter 33 Train Accuracy 0.524482109227872
# Epoch 10 Validation Accuracy 0.5833333333333334
# Epoch 11 Iter 33 Loss 1.2857490374761469
# Epoch 11 Iter 33 Train Accuracy 0.5338983050847458
# Epoch 11 Validation Accuracy 0.5833333333333334
# Epoch 12 Iter 33 Loss 1.2724451843430014
# Epoch 12 Iter 33 Train Accuracy 0.527306967984934
# Epoch 12 Validation Accuracy 0.5795454545454546
# Epoch 13 Iter 33 Loss 1.250417328932706
# Epoch 13 Iter 33 Train Accuracy 0.5470809792843692
# Epoch 13 Validation Accuracy 0.5871212121212122
# Epoch 14 Iter 33 Loss 1.249982946059283
# Epoch 14 Iter 33 Train Accuracy 0.5414312617702448
# Epoch 14 Validation Accuracy 0.5795454545454546
# Epoch 15 Iter 33 Loss 1.234406390610863
# Epoch 15 Iter 33 Train Accuracy 0.556497175141243
# Epoch 15 Validation Accuracy 0.571969696969697
# Epoch 16 Iter 33 Loss 1.2350980148595923
# Epoch 16 Iter 33 Train Accuracy 0.5433145009416196
# Epoch 16 Validation Accuracy 0.5909090909090909
# Epoch 17 Iter 33 Loss 1.223472586449455
# Epoch 17 Iter 33 Train Accuracy 0.5480225988700564
# Epoch 17 Validation Accuracy 0.5681818181818182
# Epoch 18 Iter 33 Loss 1.2196514711660498
# Epoch 18 Iter 33 Train Accuracy 0.5527306967984934
# Epoch 18 Validation Accuracy 0.5795454545454546
# Epoch 19 Iter 33 Loss 1.2085406569873585
# Epoch 19 Iter 33 Train Accuracy 0.5433145009416196
# Epoch 19 Validation Accuracy 0.5946969696969697
# Epoch 20 Iter 33 Loss 1.2133883430677301
# Epoch 20 Iter 33 Train Accuracy 0.5743879472693032
# Epoch 20 Validation Accuracy 0.5795454545454546
# Epoch 21 Iter 33 Loss 1.1974202078931473
# Epoch 21 Iter 33 Train Accuracy 0.5677966101694916
# Epoch 21 Validation Accuracy 0.5871212121212122
# Epoch 22 Iter 33 Loss 1.1974972311188192
# Epoch 22 Iter 33 Train Accuracy 0.5659133709981168
# Epoch 22 Validation Accuracy 0.5833333333333334
# Epoch 23 Iter 33 Loss 1.1947659744935877
# Epoch 23 Iter 33 Train Accuracy 0.5536723163841808
# Epoch 23 Validation Accuracy 0.5833333333333334
# Epoch 24 Iter 33 Loss 1.1956007428029005
# Epoch 24 Iter 33 Train Accuracy 0.5649717514124294
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 train_classifier(classifier, optimizer, loss_fn, dataloader_train, dataloader_val, epochs=100)
#
# Cell In[62], line 36, in train_classifier(classifier, optim, loss_fn, train_loader, val_loader, epochs)
#      34 with torch.no_grad():
#      35     for i, (wave, time,label) in enumerate(val_loader):
# ---> 36         output = classifier(wave,time)
#      37         predicted = torch.argmax(output, 1)
#      38         #print(predicted.shape)
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Cell In[61], line 24, in classification.forward(self, wave, time)
#      21 def forward(self, wave,time):
#      22     #e_wave, e_time, d_wave, d_time = self.mixedModelAE(wave,time)
#      23     e_wave,d_wave = self.wave_model(wave)
# ---> 24     e_time,d_time = self.time_model(time)
#      25     e_wave, e_time = normalize(e_wave), normalize(e_time)
#      26     #print(e_wave.shape)
#      27     #print(e_time.shape)
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Cell In[47], line 20, in UnimodalModel.forward(self, x)
#      18 x = x + torch.randn_like(x)*0.1
#      19 enc_x = self.encoder(x)
# ---> 20 dec_x = self.decoder(enc_x)
#      22 return enc_x, dec_x
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/Desktop/ephys_autoencoder/1d-constrastive-autoencoder/backbones.py:134, in ResNet18Dec.forward(self, x)
#     132 x = self.layer4(x)
#     133 x = self.layer3(x)
# --> 134 x = self.layer2(x)
#     135 x = self.layer1(x)
#     136 x = self.conv1(x)
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/Desktop/ephys_autoencoder/1d-constrastive-autoencoder/backbones.py:68, in BasicBlockDec.forward(self, x)
#      66 out = F.leaky_relu(self.bn2(self.conv2(x)))
#      67 out = self.bn1(self.conv1(out))
# ---> 68 out += self.shortcut(x)
#      69 out = F.leaky_relu(out)
#      70 return out
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/batchnorm.py:178, in _BatchNorm.forward(self, input)
#     164     bn_training = (self.running_mean is None) and (self.running_var is None)
#     166 r"""
#     167 Buffers are only updated if they are to be tracked and we are in training mode. Thus they only need to be
#     168 passed when the update should occur (i.e. in training mode when they are tracked), or when buffer stats are
#     169 used for normalization (i.e. in eval mode when buffers are not None).
#     170 """
#     171 return F.batch_norm(
#     172     input,
#     173     # If buffers are not to be tracked, ensure that they won't be updated
#     174     self.running_mean
#     175     if not self.training or self.track_running_stats
#     176     else None,
#     177     self.running_var if not self.training or self.track_running_stats else None,
# --> 178     self.weight,
#     179     self.bias,
#     180     bn_training,
#     181     exponential_average_factor,
#     182     self.eps,
#     183 )
#
# File ~/opt/miniconda3/envs/electro_phys/lib/python3.10/site-packages/torch/nn/modules/module.py:1682, in Module.__getattr__(self, name)
#    1673         self._backward_pre_hooks = OrderedDict()
#    1675 # On the return type:
#    1676 # We choose to return `Any` in the `__getattr__` type signature instead of a more strict `Union[Tensor, Module]`.
#    1677 # This is done for better interop with various type checkers for the end users.
#    (...)
#    1680 # See full discussion on the problems with returning `Union` here
#    1681 # https://github.com/microsoft/pyright/issues/4213
# -> 1682 def __getattr__(self, name: str) -> Any:
#    1683     if '_parameters' in self.__dict__:
#    1684         _parameters = self.__dict__['_parameters']
#
# KeyboardInterrupt:

# %%
def predict_classifier(classifier, dataloader):
    predictions = []
    classifier.eval()
    with torch.no_grad():
        for i, (wave, time,label) in enumerate(dataloader):
            output = classifier(wave,time)
            predicted = torch.argmax(output, 1)
            predictions.append(predicted)
    return predictions

predictions = predict_classifier(classifier, dataloader_val)
predictions = torch.cat(predictions, dim=0).detach().numpy()

# %%
#Obtain numpy array from dataloader_val
labels = np.array([label_item for _,_,label_batch in dataloader_val for label_item in label_batch])
print(labels.shape)
labels
# Out:
# (264,)
# array([4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2,
#        3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5,
#        0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1,
#        4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2,
#        3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5,
#        0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1,
#        4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2,
#        3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5,
#        0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1,
#        4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2,
#        3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5,
#        0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1, 4, 5, 0, 2, 3, 1])

# %%
preds_np = predictions
labels_np = labels

# %%
len(preds_np)
# Out:
# 264

# %%
preds_np
# Out:
# array(['VGAT', 'VIP', 'VIP', 'Pyra', 'VIP', 'PV', 'SST', 'PV', 'VIP',
#        'Pyra', 'PV', 'VIP', 'VGAT', 'PV', 'VGAT', 'Pyra', 'VGAT', 'PV',
#        'VGAT', 'VIP', 'Pyra', 'Pyra', 'PV', 'VGAT', 'VGAT', 'VIP', 'SST',
#        'Pyra', 'VGAT', 'SST', 'VGAT', 'VIP', 'VIP', 'Pyra', 'SST', 'PV',
#        'VGAT', 'VIP', 'Pyra', 'Pyra', 'PV', 'PV', 'VGAT', 'VIP', 'VIP',
#        'Pyra', 'SST', 'PV', 'VGAT', 'PV', 'SST', 'Pyra', 'PV', 'PV',
#        'VGAT', 'VIP', 'VIP', 'Pyra', 'PV', 'PV', 'VGAT', 'VIP', 'VGAT',
#        'Pyra', 'VIP', 'VGAT', 'SST', 'PV', 'SST', 'Pyra', 'PV', 'PV',
#        'VGAT', 'VIP', 'SST', 'Pyra', 'PV', 'PV', 'VGAT', 'VIP', 'Pyra',
#        'Pyra', 'PV', 'PV', 'VGAT', 'VIP', 'SST', 'Pyra', 'VGAT', 'SST',
#        'VGAT', 'VIP', 'VGAT', 'Pyra', 'VIP', 'PV', 'VGAT', 'VIP', 'SST',
#        'Pyra', 'VIP', 'PV', 'VGAT', 'PV', 'SST', 'Pyra', 'PV', 'SST',
#        'VGAT', 'VIP', 'Pyra', 'Pyra', 'PV', 'VGAT', 'VGAT', 'VIP', 'VGAT',
#        'Pyra', 'VIP', 'PV', 'VGAT', 'VIP', 'VIP', 'Pyra', 'PV', 'VGAT',
#        'VGAT', 'VIP', 'Pyra', 'Pyra', 'SST', 'PV', 'VGAT', 'VIP', 'VIP',
#        'Pyra', 'PV', 'PV', 'VGAT', 'VIP', 'VGAT', 'Pyra', 'PV', 'PV',
#        'VGAT', 'PV', 'Pyra', 'Pyra', 'PV', 'PV', 'VGAT', 'VIP', 'SST',
#        'Pyra', 'PV', 'VGAT', 'VGAT', 'VIP', 'SST', 'Pyra', 'VGAT', 'SST',
#        'VGAT', 'VIP', 'VGAT', 'Pyra', 'PV', 'SST', 'VGAT', 'VIP', 'SST',
#        'Pyra', 'VIP', 'SST', 'VGAT', 'VIP', 'Pyra', 'Pyra', 'SST', 'PV',
#        'VGAT', 'VIP', 'VGAT', 'Pyra', 'PV', 'PV', 'VGAT', 'PV', 'Pyra',
#        'Pyra', 'PV', 'PV', 'VIP', 'VIP', 'Pyra', 'Pyra', 'PV', 'PV',
#        'VGAT', 'VIP', 'Pyra', 'Pyra', 'VGAT', 'SST', 'VGAT', 'VIP',
#        'VGAT', 'Pyra', 'VIP', 'PV', 'VGAT', 'VIP', 'Pyra', 'Pyra', 'SST',
#        'PV', 'VGAT', 'VIP', 'VIP', 'Pyra', 'VIP', 'Juxt', 'VGAT', 'VIP',
#        'Pyra', 'Pyra', 'VIP', 'PV', 'VGAT', 'PV', 'VGAT', 'Pyra', 'PV',
#        'PV', 'VIP', 'VIP', 'SST', 'Pyra', 'VGAT', 'PV', 'VGAT', 'VIP',
#        'SST', 'Pyra', 'VGAT', 'PV', 'SST', 'VIP', 'VGAT', 'Pyra', 'VIP',
#        'VGAT', 'VGAT', 'VIP', 'VIP', 'Pyra', 'PV', 'PV', 'SST', 'VIP',
#        'SST', 'Pyra', 'VGAT', 'PV'], dtype=object)

# %%
#Value counts of predictions
Counter(preds_np)
#Value counts of labels
Counter(labels_np)
#Plot barplots of predictions and labels
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.bar(Counter(preds_np).keys(), Counter(preds_np).values())   
plt.subplot(1, 2, 2)
plt.bar(Counter(labels_np).keys(), Counter(labels_np).values())
#Title
plt.suptitle('Predictions and Labels')
# Out:
# Text(0.5, 0.98, 'Predictions and Labels')

# %%
# Compute confusion matrix
cm = confusion_matrix(labels_np, preds_np, normalize='true')

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=le.inverse_transform([0,1,2,3,4,5]))
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 2
#       1 # Compute confusion matrix
# ----> 2 cm = confusion_matrix(labels_np, preds_np, normalize='true')
#       4 # Plot confusion matrix
#       5 disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=le.inverse_transform([0,1,2,3,4,5]))
#
# NameError: name 'labels_np' is not defined

# %%
# class classification_unimodal(nn.Module):
#     def __init__(self, num_labels, **kwargs):
#         super().__init__()
#         #self.mixedModelAE = MixedModel(**kwargs)
#         #self.mixedModelAE.load_state_dict(torch.load('MixedAutoEncoderTemplates.pt'))
#         self.wave_model = UnimodalModel(z_dim=5,output_size=50)
#         self.wave_model.load_state_dict(torch.load('./unimodal_model/wave_model_50_finetuned.pt'))
#         for p in self.wave_model.parameters():
#             p.requires_grad = False
        
#         self.classifier = nn.Sequential(nn.Linear(kwargs['z_dim'], 64), nn.ReLU(),
#                                          nn.Linear(64, num_labels))
#         #self.classifier = nn.Sequential(nn.Linear(64 * 2, num_labels))
        

#     def forward(self, wave):
#         #e_wave, e_time, d_wave, d_time = self.mixedModelAE(wave,time)
#         e_wave,d_wave = self.wave_model(wave)
#         e_wave = normalize(e_wave)
#         #print(e_wave.shape)
#         #print(e_time.shape)
#         #x = torch.cat((e_wave, e_time), dim=-1).squeeze()
#         x = e_wave.squeeze()
#         #print(x.shape)
#         output = self.classifier(x)    
#         #print(output.shape)    
#         return output

# %%
# classifier = classification_unimodal(num_labels=6, z_dim=5)
# optimizer = torch.optim.AdamW(classifier.parameters(), lr=0.001)
# loss_fn = nn.CrossEntropyLoss()

# #Training the classifier

# import matplotlib.pyplot as plt
# from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay



# def train_classifier(classifier, optim, loss_fn, train_loader, val_loader, epochs=10):
#     for epoch in range(epochs):
#         cum_loss = 0
#         classifier.train()
#         correct_train = 0
#         total_train = 0
#         for i, (wave, time,label) in enumerate(train_loader):
#             optimizer.zero_grad()
#             output = classifier(wave)
#             train_predicted = torch.argmax(output, 1)
#             total_train += time.size(0)
#             correct_train += (train_predicted == label).sum().item()
#             loss = loss_fn(output,label)
#             cum_loss += loss.item()
#             loss.backward()
#             optimizer.step()
#         print(f"Epoch {epoch} Iter {i} Loss {cum_loss/len(train_loader)}")
#         print(f"Epoch {epoch} Iter {i} Train Accuracy {correct_train / total_train}")
#         classifier.eval()
#         correct = 0
#         total = 0
        
#         with torch.no_grad():
#             for i, (wave, time,label) in enumerate(val_loader):
#                 output = classifier(wave)
#                 predicted = torch.argmax(output, 1)
#                 #print(predicted.shape)
#                 total += time.size(0)
#                 correct += (predicted == label).sum().item()
#             print(f"Epoch {epoch} Validation Accuracy {correct / total}")

# %%
# train_classifier(classifier, optimizer, loss_fn, dataloader_train, dataloader_val, epochs=100)
# Out:
# Epoch 0 Iter 30 Loss 1.8034318902275779
# Epoch 0 Iter 30 Train Accuracy 0.23336745138178097
# Epoch 0 Validation Accuracy 0.38223938223938225
# Epoch 1 Iter 32 Loss 1.8490772319562507
# Epoch 1 Iter 32 Train Accuracy 0.3930968360498562
# Epoch 1 Validation Accuracy 0.41312741312741313
# Epoch 2 Iter 32 Loss 1.7725415482665554
# Epoch 2 Iter 32 Train Accuracy 0.42377756471716205
# Epoch 2 Validation Accuracy 0.39768339768339767
# Epoch 3 Iter 32 Loss 1.6979312282620054
# Epoch 3 Iter 32 Train Accuracy 0.45158197507190795
# Epoch 3 Validation Accuracy 0.4015444015444015
# Epoch 4 Iter 32 Loss 1.6332472309921726
# Epoch 4 Iter 32 Train Accuracy 0.45254074784276127
# Epoch 4 Validation Accuracy 0.4092664092664093
# Epoch 5 Iter 32 Loss 1.580764109438116
# Epoch 5 Iter 32 Train Accuracy 0.4621284755512943
# Epoch 5 Validation Accuracy 0.4362934362934363
# Epoch 6 Iter 32 Loss 1.543112910155094
# Epoch 6 Iter 32 Train Accuracy 0.47555129434324067
# Epoch 6 Validation Accuracy 0.42084942084942084
# Epoch 7 Iter 32 Loss 1.5148646939884534
# Epoch 7 Iter 32 Train Accuracy 0.48897411313518696
# Epoch 7 Validation Accuracy 0.4247104247104247
# Epoch 8 Iter 32 Loss 1.4797246239402078
# Epoch 8 Iter 32 Train Accuracy 0.4928092042186002
# Epoch 8 Validation Accuracy 0.4247104247104247
# Epoch 9 Iter 32 Loss 1.4704611229174065
# Epoch 9 Iter 32 Train Accuracy 0.5004793863854267
# Epoch 9 Validation Accuracy 0.416988416988417
# Epoch 10 Iter 32 Loss 1.4505387291763767
# Epoch 10 Iter 32 Train Accuracy 0.4947267497603068
# Epoch 10 Validation Accuracy 0.4092664092664093
# Epoch 11 Iter 32 Loss 1.4316966064048535
# Epoch 11 Iter 32 Train Accuracy 0.4947267497603068
# Epoch 11 Validation Accuracy 0.416988416988417
# Epoch 12 Iter 32 Loss 1.4262420517025571
# Epoch 12 Iter 32 Train Accuracy 0.4851390220517737
# Epoch 12 Validation Accuracy 0.4015444015444015
# Epoch 13 Iter 32 Loss 1.4066662391026814
# Epoch 13 Iter 32 Train Accuracy 0.49952061361457334
# Epoch 13 Validation Accuracy 0.41312741312741313
# Epoch 14 Iter 32 Loss 1.392960624261336
# Epoch 14 Iter 32 Train Accuracy 0.4899328859060403
# Epoch 14 Validation Accuracy 0.42084942084942084
# Epoch 15 Iter 32 Loss 1.3839452049948953
# Epoch 15 Iter 32 Train Accuracy 0.5043144774688398
# Epoch 15 Validation Accuracy 0.43243243243243246
# Epoch 16 Iter 32 Loss 1.36962573817282
# Epoch 16 Iter 32 Train Accuracy 0.513902205177373
# Epoch 16 Validation Accuracy 0.4362934362934363
# Epoch 17 Iter 32 Loss 1.364078203837077
# Epoch 17 Iter 32 Train Accuracy 0.5091083413231065
# Epoch 17 Validation Accuracy 0.43243243243243246
# Epoch 18 Iter 32 Loss 1.3602403871940845
# Epoch 18 Iter 32 Train Accuracy 0.5023969319271333
# Epoch 18 Validation Accuracy 0.416988416988417
# Epoch 19 Iter 32 Loss 1.3462766589540425
# Epoch 19 Iter 32 Train Accuracy 0.49952061361457334
# Epoch 19 Validation Accuracy 0.4247104247104247
# Epoch 20 Iter 32 Loss 1.3466551050995335
# Epoch 20 Iter 32 Train Accuracy 0.5071907957813998
# Epoch 20 Validation Accuracy 0.4247104247104247
# Epoch 21 Iter 32 Loss 1.336119052135583
# Epoch 21 Iter 32 Train Accuracy 0.5052732502396932
# Epoch 21 Validation Accuracy 0.42857142857142855
# Epoch 22 Iter 32 Loss 1.3243216276168823
# Epoch 22 Iter 32 Train Accuracy 0.5244487056567594
# Epoch 22 Validation Accuracy 0.42084942084942084
# Epoch 23 Iter 32 Loss 1.3262159246386904
# Epoch 23 Iter 32 Train Accuracy 0.50143815915628
# Epoch 23 Validation Accuracy 0.4247104247104247
# Epoch 24 Iter 32 Loss 1.325182141679706
# Epoch 24 Iter 32 Train Accuracy 0.5100671140939598
# Epoch 24 Validation Accuracy 0.444015444015444
# Epoch 25 Iter 32 Loss 1.3154823527191624
# Epoch 25 Iter 32 Train Accuracy 0.5129434324065196
# Epoch 25 Validation Accuracy 0.44015444015444016
# Epoch 26 Iter 32 Loss 1.3227008003177065
# Epoch 26 Iter 32 Train Accuracy 0.5062320230105465
# Epoch 26 Validation Accuracy 0.4362934362934363
# Epoch 27 Iter 32 Loss 1.3054334430983572
# Epoch 27 Iter 32 Train Accuracy 0.5081495685522531
# Epoch 27 Validation Accuracy 0.416988416988417
# Epoch 28 Iter 32 Loss 1.3128884705630215
# Epoch 28 Iter 32 Train Accuracy 0.5119846596356663
# Epoch 28 Validation Accuracy 0.43243243243243246
# Epoch 29 Iter 32 Loss 1.2985446127978237
# Epoch 29 Iter 32 Train Accuracy 0.5177372962607862
# Epoch 29 Validation Accuracy 0.4092664092664093
# Epoch 30 Iter 32 Loss 1.295072418270689
# Epoch 30 Iter 32 Train Accuracy 0.5129434324065196
# Epoch 30 Validation Accuracy 0.43243243243243246
# Epoch 31 Iter 32 Loss 1.281902222922354
# Epoch 31 Iter 32 Train Accuracy 0.5071907957813998
# Epoch 31 Validation Accuracy 0.41312741312741313
# Epoch 32 Iter 32 Loss 1.2849788160035105
# Epoch 32 Iter 32 Train Accuracy 0.5167785234899329
# Epoch 32 Validation Accuracy 0.444015444015444
# Epoch 33 Iter 32 Loss 1.2829832777832493
# Epoch 33 Iter 32 Train Accuracy 0.5158197507190796
# Epoch 33 Validation Accuracy 0.444015444015444
# Epoch 34 Iter 32 Loss 1.288495219115055
# Epoch 34 Iter 32 Train Accuracy 0.5043144774688398
# Epoch 34 Validation Accuracy 0.444015444015444
# Epoch 35 Iter 32 Loss 1.2835212151209514
# Epoch 35 Iter 32 Train Accuracy 0.5244487056567594
# Epoch 35 Validation Accuracy 0.46332046332046334
# Epoch 36 Iter 32 Loss 1.2730719681942102
# Epoch 36 Iter 32 Train Accuracy 0.513902205177373
# Epoch 36 Validation Accuracy 0.43243243243243246
# Epoch 37 Iter 32 Loss 1.2686425880952314
# Epoch 37 Iter 32 Train Accuracy 0.5071907957813998
# Epoch 37 Validation Accuracy 0.4092664092664093
# Epoch 38 Iter 32 Loss 1.2624929149945576
# Epoch 38 Iter 32 Train Accuracy 0.5177372962607862
# Epoch 38 Validation Accuracy 0.43243243243243246
# Epoch 39 Iter 32 Loss 1.263756806200201
# Epoch 39 Iter 32 Train Accuracy 0.5225311601150527
# Epoch 39 Validation Accuracy 0.4362934362934363
# Epoch 40 Iter 32 Loss 1.2721495267116663
# Epoch 40 Iter 32 Train Accuracy 0.5215723873441994
# Epoch 40 Validation Accuracy 0.416988416988417
# Epoch 41 Iter 32 Loss 1.26831076000676
# Epoch 41 Iter 32 Train Accuracy 0.5119846596356663
# Epoch 41 Validation Accuracy 0.4362934362934363
# Epoch 42 Iter 32 Loss 1.2605995012052131
# Epoch 42 Iter 32 Train Accuracy 0.5119846596356663
# Epoch 42 Validation Accuracy 0.4247104247104247
# Epoch 43 Iter 32 Loss 1.265830327164043
# Epoch 43 Iter 32 Train Accuracy 0.5129434324065196
# Epoch 43 Validation Accuracy 0.4247104247104247
# Epoch 44 Iter 32 Loss 1.257189084183086
# Epoch 44 Iter 32 Train Accuracy 0.5225311601150527
# Epoch 44 Validation Accuracy 0.444015444015444
# Epoch 45 Iter 32 Loss 1.2799806793530781
# Epoch 45 Iter 32 Train Accuracy 0.49952061361457334
# Epoch 45 Validation Accuracy 0.43243243243243246
# Epoch 46 Iter 32 Loss 1.2579884800043972
# Epoch 46 Iter 32 Train Accuracy 0.5215723873441994
# Epoch 46 Validation Accuracy 0.43243243243243246
# Epoch 47 Iter 32 Loss 1.2611697388417793
# Epoch 47 Iter 32 Train Accuracy 0.5100671140939598
# Epoch 47 Validation Accuracy 0.43243243243243246
# Epoch 48 Iter 32 Loss 1.2616365750630696
# Epoch 48 Iter 32 Train Accuracy 0.5206136145733461
# Epoch 48 Validation Accuracy 0.4362934362934363
# Epoch 49 Iter 32 Loss 1.2467207330645937
# Epoch 49 Iter 32 Train Accuracy 0.5186960690316395
# Epoch 49 Validation Accuracy 0.41312741312741313
# Epoch 50 Iter 32 Loss 1.2633908228440718
# Epoch 50 Iter 32 Train Accuracy 0.5052732502396932
# Epoch 50 Validation Accuracy 0.4362934362934363
# Epoch 51 Iter 32 Loss 1.2426104021794868
# Epoch 51 Iter 32 Train Accuracy 0.5186960690316395
# Epoch 51 Validation Accuracy 0.44015444015444016
# Epoch 52 Iter 32 Loss 1.248267361612031
# Epoch 52 Iter 32 Train Accuracy 0.5186960690316395
# Epoch 52 Validation Accuracy 0.44015444015444016
# Epoch 53 Iter 32 Loss 1.2526402762441924
# Epoch 53 Iter 32 Train Accuracy 0.5196548418024928
# Epoch 53 Validation Accuracy 0.41312741312741313
# Epoch 54 Iter 32 Loss 1.23658722819704
# Epoch 54 Iter 32 Train Accuracy 0.5234899328859061
# Epoch 54 Validation Accuracy 0.4247104247104247
# Epoch 55 Iter 32 Loss 1.2441249200792024
# Epoch 55 Iter 32 Train Accuracy 0.5091083413231065
# Epoch 55 Validation Accuracy 0.444015444015444
# Epoch 56 Iter 32 Loss 1.2246361862529407
# Epoch 56 Iter 32 Train Accuracy 0.5321188878235859
# Epoch 56 Validation Accuracy 0.43243243243243246
# Epoch 57 Iter 32 Loss 1.2489691972732544
# Epoch 57 Iter 32 Train Accuracy 0.5071907957813998
# Epoch 57 Validation Accuracy 0.44015444015444016
# Epoch 58 Iter 32 Loss 1.2332356626337224
# Epoch 58 Iter 32 Train Accuracy 0.5119846596356663
# Epoch 58 Validation Accuracy 0.444015444015444
# Epoch 59 Iter 32 Loss 1.2224055167400476
# Epoch 59 Iter 32 Train Accuracy 0.5311601150527325
# Epoch 59 Validation Accuracy 0.44015444015444016
# Epoch 60 Iter 32 Loss 1.2372386130419644
# Epoch 60 Iter 32 Train Accuracy 0.5321188878235859
# Epoch 60 Validation Accuracy 0.44015444015444016
# Epoch 61 Iter 32 Loss 1.237109287218614
# Epoch 61 Iter 32 Train Accuracy 0.5148609779482263
# Epoch 61 Validation Accuracy 0.444015444015444
# Epoch 62 Iter 32 Loss 1.238816347989169
# Epoch 62 Iter 32 Train Accuracy 0.5177372962607862
# Epoch 62 Validation Accuracy 0.44787644787644787
# Epoch 63 Iter 32 Loss 1.2499461914553787
# Epoch 63 Iter 32 Train Accuracy 0.5081495685522531
# Epoch 63 Validation Accuracy 0.42857142857142855
# Epoch 64 Iter 32 Loss 1.2222898783105793
# Epoch 64 Iter 32 Train Accuracy 0.5349952061361457
# Epoch 64 Validation Accuracy 0.416988416988417
# Epoch 65 Iter 32 Loss 1.232996227163257
# Epoch 65 Iter 32 Train Accuracy 0.5186960690316395
# Epoch 65 Validation Accuracy 0.4594594594594595
# Epoch 66 Iter 32 Loss 1.2369128826892737
# Epoch 66 Iter 32 Train Accuracy 0.5292425695110259
# Epoch 66 Validation Accuracy 0.4092664092664093
# Epoch 67 Iter 32 Loss 1.2313335447600393
# Epoch 67 Iter 32 Train Accuracy 0.5234899328859061
# Epoch 67 Validation Accuracy 0.4247104247104247
# Epoch 68 Iter 32 Loss 1.2285300583550425
# Epoch 68 Iter 32 Train Accuracy 0.5196548418024928
# Epoch 68 Validation Accuracy 0.43243243243243246
# Epoch 69 Iter 32 Loss 1.2236608086210308
# Epoch 69 Iter 32 Train Accuracy 0.5263662511984659
# Epoch 69 Validation Accuracy 0.444015444015444
# Epoch 70 Iter 32 Loss 1.2209611914374612
# Epoch 70 Iter 32 Train Accuracy 0.5397890699904123
# Epoch 70 Validation Accuracy 0.42084942084942084
# Epoch 71 Iter 32 Loss 1.2225082841786472
# Epoch 71 Iter 32 Train Accuracy 0.5263662511984659
# Epoch 71 Validation Accuracy 0.4362934362934363
# Epoch 72 Iter 32 Loss 1.2174850792595835
# Epoch 72 Iter 32 Train Accuracy 0.5215723873441994
# Epoch 72 Validation Accuracy 0.42857142857142855
# Epoch 73 Iter 32 Loss 1.2213450399312107
# Epoch 73 Iter 32 Train Accuracy 0.5167785234899329
# Epoch 73 Validation Accuracy 0.444015444015444
# Epoch 74 Iter 32 Loss 1.2117778171192517
# Epoch 74 Iter 32 Train Accuracy 0.5273250239693192
# Epoch 74 Validation Accuracy 0.4594594594594595
# Epoch 75 Iter 32 Loss 1.23337869571917
# Epoch 75 Iter 32 Train Accuracy 0.513902205177373
# Epoch 75 Validation Accuracy 0.4247104247104247
# Epoch 76 Iter 32 Loss 1.2087023402705337
# Epoch 76 Iter 32 Train Accuracy 0.535953978906999
# Epoch 76 Validation Accuracy 0.444015444015444
# Epoch 77 Iter 32 Loss 1.2134826941923662
# Epoch 77 Iter 32 Train Accuracy 0.5206136145733461
# Epoch 77 Validation Accuracy 0.4517374517374517
# Epoch 78 Iter 32 Loss 1.2161051161361462
# Epoch 78 Iter 32 Train Accuracy 0.5177372962607862
# Epoch 78 Validation Accuracy 0.4555984555984556
# Epoch 79 Iter 32 Loss 1.2212015318148064
# Epoch 79 Iter 32 Train Accuracy 0.5177372962607862
# Epoch 79 Validation Accuracy 0.4247104247104247
# Epoch 80 Iter 32 Loss 1.2175384362538655
# Epoch 80 Iter 32 Train Accuracy 0.5234899328859061
# Epoch 80 Validation Accuracy 0.46332046332046334
# Epoch 81 Iter 32 Loss 1.2202513561104282
# Epoch 81 Iter 32 Train Accuracy 0.5186960690316395
# Epoch 81 Validation Accuracy 0.444015444015444
# Epoch 82 Iter 32 Loss 1.205136402086778
# Epoch 82 Iter 32 Train Accuracy 0.5158197507190796
# Epoch 82 Validation Accuracy 0.42084942084942084
# Epoch 83 Iter 32 Loss 1.2225580486384304
# Epoch 83 Iter 32 Train Accuracy 0.5215723873441994
# Epoch 83 Validation Accuracy 0.43243243243243246
# Epoch 84 Iter 32 Loss 1.2103610761237866
# Epoch 84 Iter 32 Train Accuracy 0.5292425695110259
# Epoch 84 Validation Accuracy 0.4517374517374517
# Epoch 85 Iter 32 Loss 1.2050032073801213
# Epoch 85 Iter 32 Train Accuracy 0.5302013422818792
# Epoch 85 Validation Accuracy 0.44787644787644787
# Epoch 86 Iter 32 Loss 1.219789187113444
# Epoch 86 Iter 32 Train Accuracy 0.5215723873441994
# Epoch 86 Validation Accuracy 0.42084942084942084
# Epoch 87 Iter 32 Loss 1.2050954482772134
# Epoch 87 Iter 32 Train Accuracy 0.5292425695110259
# Epoch 87 Validation Accuracy 0.44787644787644787
# Epoch 88 Iter 32 Loss 1.2082052212772947
# Epoch 88 Iter 32 Train Accuracy 0.5186960690316395
# Epoch 88 Validation Accuracy 0.42857142857142855
# Epoch 89 Iter 32 Loss 1.2015808314988108
# Epoch 89 Iter 32 Train Accuracy 0.5321188878235859
# Epoch 89 Validation Accuracy 0.44787644787644787
# Epoch 90 Iter 32 Loss 1.1963670073133525
# Epoch 90 Iter 32 Train Accuracy 0.535953978906999
# Epoch 90 Validation Accuracy 0.4555984555984556
# Epoch 91 Iter 32 Loss 1.2021064577680645
# Epoch 91 Iter 32 Train Accuracy 0.538830297219559
# Epoch 91 Validation Accuracy 0.42857142857142855
# Epoch 92 Iter 32 Loss 1.1964001294338342
# Epoch 92 Iter 32 Train Accuracy 0.5349952061361457
# Epoch 92 Validation Accuracy 0.42857142857142855
# Epoch 93 Iter 32 Loss 1.2087835163781138
# Epoch 93 Iter 32 Train Accuracy 0.5349952061361457
# Epoch 93 Validation Accuracy 0.43243243243243246
# Epoch 94 Iter 32 Loss 1.2070984443028767
# Epoch 94 Iter 32 Train Accuracy 0.5282837967401726
# Epoch 94 Validation Accuracy 0.42857142857142855
# Epoch 95 Iter 32 Loss 1.2085919777552288
# Epoch 95 Iter 32 Train Accuracy 0.5119846596356663
# Epoch 95 Validation Accuracy 0.4555984555984556
# Epoch 96 Iter 32 Loss 1.1996066823150173
# Epoch 96 Iter 32 Train Accuracy 0.5330776605944392
# Epoch 96 Validation Accuracy 0.46332046332046334
# Epoch 97 Iter 32 Loss 1.1946531118768635
# Epoch 97 Iter 32 Train Accuracy 0.5397890699904123
# Epoch 97 Validation Accuracy 0.4594594594594595
# Epoch 98 Iter 32 Loss 1.1792815815318713
# Epoch 98 Iter 32 Train Accuracy 0.538830297219559
# Epoch 98 Validation Accuracy 0.444015444015444
# Epoch 99 Iter 32 Loss 1.1999728282292683
# Epoch 99 Iter 32 Train Accuracy 0.5311601150527325
# Epoch 99 Validation Accuracy 0.4594594594594595

# %%
# def predict_classifier(classifier, dataloader):
#     predictions = []
#     classifier.eval()
#     with torch.no_grad():
#         for i, (wave, time,label) in enumerate(dataloader):
#             output = classifier(wave)
#             predicted = torch.argmax(output, 1)
#             predictions.append(predicted)
#     return predictions

# predictions = predict_classifier(classifier, dataloader_val)
# predictions = torch.cat(predictions, dim=0).detach().numpy()
# labels = np.array([label_item for _,_,label_batch in dataloader_val for label_item in label_batch])

# %%
# print(labels.shape)
# preds_np = predictions
# labels_np = labels

# # Compute confusion matrix
# cm = confusion_matrix(labels_np[:223], preds_np[:223], normalize='true')

# # Plot confusion matrix
# disp = ConfusionMatrixDisplay(confusion_matrix=cm)
# disp.plot(cmap=plt.cm.Blues)
# plt.show()
# Out:
# (259,)
